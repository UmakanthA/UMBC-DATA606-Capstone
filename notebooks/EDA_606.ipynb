# %%
import pandas as pd

# %% [markdown]
# # Exploring the CDC Data

# %%
df1 = pd.read_csv("S:/UMBC 4th Sem/Dataset.csv")

# %%
df1.describe()
# Out:
#           YearStart       YearEnd  Data_Value_Unit    Data_Value  \
# count  93249.000000  93249.000000              0.0  84014.000000
# mean    2016.308068   2016.308068              NaN     31.226492
# std        3.308679      3.308679              NaN     10.021059
# min     2011.000000   2011.000000              NaN      0.900000
# 25%     2013.000000   2013.000000              NaN     24.400000
# 50%     2017.000000   2017.000000              NaN     31.200000
# 75%     2019.000000   2019.000000              NaN     37.000000
# max     2022.000000   2022.000000              NaN     77.600000
#
#        Data_Value_Alt  Low_Confidence_Limit  High_Confidence_Limit   \
# count    84014.000000          84014.000000            84014.000000
# mean        31.226492             26.890256               36.134303
# std         10.021059              9.816064               10.978276
# min          0.900000              0.300000                3.000000
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 93249 entries, 0 to 93248
# Data columns (total 33 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   YearStart                   93249 non-null  int64
#  1   YearEnd                     93249 non-null  int64
#  2   LocationAbbr                93249 non-null  object
#  3   LocationDesc                93249 non-null  object
#  4   Datasource                  93249 non-null  object
#  5   Class                       93249 non-null  object
#  6   Topic                       93249 non-null  object
#  7   Question                    93249 non-null  object
#  8   Data_Value_Unit             0 non-null      float64
#  9   Data_Value_Type             93249 non-null  object
#  10  Data_Value                  84014 non-null  float64
#  11  Data_Value_Alt              84014 non-null  float64
#  12  Data_Value_Footnote_Symbol  9235 non-null   object
# ...

# %%
df1.head(5)
# Out:
#    YearStart  YearEnd LocationAbbr LocationDesc  \
# 0       2020     2020           US     National
# 1       2014     2014           GU         Guam
# 2       2013     2013           US     National
# 3       2013     2013           US     National
# 4       2015     2015           US     National
#
#                                    Datasource                    Class  \
# 0  Behavioral Risk Factor Surveillance System        Physical Activity
# 1  Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 2  Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 3  Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 4  Behavioral Risk Factor Surveillance System        Physical Activity
#
#                           Topic  \
# 0  Physical Activity - Behavior
# 1       Obesity / Weight Status
# 2       Obesity / Weight Status
# 3       Obesity / Weight Status
# 4  Physical Activity - Behavior
#
# ...

# %%
df1.tail(5)
# Out:
#        YearStart  YearEnd LocationAbbr LocationDesc Datasource  \
# 93244       2022     2022           WY      Wyoming      BRFSS
# 93245       2022     2022           WY      Wyoming      BRFSS
# 93246       2022     2022           WY      Wyoming      BRFSS
# 93247       2022     2022           WY      Wyoming      BRFSS
# 93248       2022     2022           WY      Wyoming      BRFSS
#
#                          Class                         Topic  \
# 93244  Obesity / Weight Status       Obesity / Weight Status
# 93245        Physical Activity  Physical Activity - Behavior
# 93246  Obesity / Weight Status       Obesity / Weight Status
# 93247  Obesity / Weight Status       Obesity / Weight Status
# 93248  Obesity / Weight Status       Obesity / Weight Status
#
#                                                 Question  Data_Value_Unit  \
# 93244  Percent of adults aged 18 years and older who ...              NaN
# ...

# %%
df1.sort_values("YearStart")
# Out:
#        YearStart  YearEnd LocationAbbr   LocationDesc  \
# 45318       2011     2011           NJ     New Jersey
# 69137       2011     2011           OH           Ohio
# 69135       2011     2011           AK         Alaska
# 69134       2011     2011           WV  West Virginia
# 38693       2011     2011           NJ     New Jersey
# ...          ...      ...          ...            ...
# 90165       2022     2022           KS         Kansas
# 90164       2022     2022           KS         Kansas
# 90163       2022     2022           KS         Kansas
# 90071       2022     2022           IL       Illinois
# 93248       2022     2022           WY        Wyoming
#
#                                        Datasource                    Class  \
# 45318  Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 69137  Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 69135  Behavioral Risk Factor Surveillance System        Physical Activity
# ...

# %% [markdown]
# # Basic visualizations of some of the important columns

# %%
# Count the number of occurrences for each class
class_counts = df1['Class'].value_counts()

# Pie chart
plt.figure(figsize=(8, 8))
plt.pie(class_counts, labels=class_counts.index, autopct='%1.1f%%', startangle=140)
plt.title('Distribution of Classes')
plt.axis('equal')
plt.show()

# %% [markdown]
# # Boxplot of Obesity Data by Income

# %%
income_obesity_data = df1[df1['Income'].notnull() & df1['Data_Value'].notnull()]


plt.figure(figsize=(12, 8))
sns.boxplot(x='Income', y='Data_Value', data=income_obesity_data, palette='Set3')
plt.xlabel('Income')
plt.ylabel('Obesity (Data Value)')
plt.title('Income Distribution vs. Obesity')
plt.xticks(rotation=45)
plt.show()
