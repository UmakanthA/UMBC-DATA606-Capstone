# %%
import pandas as pd

# %%
df1 = pd.read_csv("S:/UMBC 4th Sem/Dataset.csv")

# %%
df1.describe()
# Out:
#           YearStart       YearEnd  Data_Value_Unit    Data_Value  \
# count  93249.000000  93249.000000              0.0  84014.000000
# mean    2016.308068   2016.308068              NaN     31.226492
# std        3.308679      3.308679              NaN     10.021059
# min     2011.000000   2011.000000              NaN      0.900000
# 25%     2013.000000   2013.000000              NaN     24.400000
# 50%     2017.000000   2017.000000              NaN     31.200000
# 75%     2019.000000   2019.000000              NaN     37.000000
# max     2022.000000   2022.000000              NaN     77.600000
#
#        Data_Value_Alt  Low_Confidence_Limit  High_Confidence_Limit   \
# count    84014.000000          84014.000000            84014.000000
# mean        31.226492             26.890256               36.134303
# std         10.021059              9.816064               10.978276
# min          0.900000              0.300000                3.000000
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 93249 entries, 0 to 93248
# Data columns (total 33 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   YearStart                   93249 non-null  int64
#  1   YearEnd                     93249 non-null  int64
#  2   LocationAbbr                93249 non-null  object
#  3   LocationDesc                93249 non-null  object
#  4   Datasource                  93249 non-null  object
#  5   Class                       93249 non-null  object
#  6   Topic                       93249 non-null  object
#  7   Question                    93249 non-null  object
#  8   Data_Value_Unit             0 non-null      float64
#  9   Data_Value_Type             93249 non-null  object
#  10  Data_Value                  84014 non-null  float64
#  11  Data_Value_Alt              84014 non-null  float64
#  12  Data_Value_Footnote_Symbol  9235 non-null   object
# ...

# %%
df1.head(20)
# Out:
#     YearStart  YearEnd LocationAbbr          LocationDesc  \
# 0        2020     2020           US              National
# 1        2014     2014           GU                  Guam
# 2        2013     2013           US              National
# 3        2013     2013           US              National
# 4        2015     2015           US              National
# 5        2015     2015           GU                  Guam
# 6        2012     2012           WY               Wyoming
# 7        2012     2012           DC  District of Columbia
# 8        2015     2015           PR           Puerto Rico
# 9        2011     2011           AL               Alabama
# 10       2015     2015           GU                  Guam
# 11       2015     2015           RI          Rhode Island
# 12       2011     2011           US              National
# 13       2012     2012           WY               Wyoming
# 14       2020     2020           DE              Delaware
# ...

# %%
df1.tail(20)
# Out:
#        YearStart  YearEnd LocationAbbr LocationDesc Datasource  \
# 93229       2022     2022           WY      Wyoming      BRFSS
# 93230       2022     2022           WY      Wyoming      BRFSS
# 93231       2022     2022           WY      Wyoming      BRFSS
# 93232       2022     2022           WY      Wyoming      BRFSS
# 93233       2022     2022           WY      Wyoming      BRFSS
# 93234       2022     2022           WY      Wyoming      BRFSS
# 93235       2022     2022           WY      Wyoming      BRFSS
# 93236       2022     2022           WY      Wyoming      BRFSS
# 93237       2022     2022           WY      Wyoming      BRFSS
# 93238       2022     2022           WY      Wyoming      BRFSS
# 93239       2022     2022           WY      Wyoming      BRFSS
# 93240       2022     2022           WY      Wyoming      BRFSS
# 93241       2022     2022           WY      Wyoming      BRFSS
# 93242       2022     2022           WY      Wyoming      BRFSS
# ...

# %%
df1.nunique()
# Out:
# YearStart                       12
# YearEnd                         12
# LocationAbbr                    55
# LocationDesc                    55
# Datasource                       2
# Class                            3
# Topic                            3
# Question                         9
# Data_Value_Unit                  0
# Data_Value_Type                  1
# Data_Value                     695
# Data_Value_Alt                 695
# Data_Value_Footnote_Symbol       1
# Data_Value_Footnote              1
# Low_Confidence_Limit           666
# High_Confidence_Limit          761
# Sample_Size                   9761
# Total                            1
# Age(years)                       6
# Education                        4
# Gender                           2
# Income                           7
# Race/Ethnicity                   8
# GeoLocation                    105
# ClassID                          3
# TopicID                          3
# QuestionID                       9
# ...

# %%
df1.isnull()
# Out:
#        YearStart  YearEnd  LocationAbbr  LocationDesc  Datasource  Class  \
# 0          False    False         False         False       False  False
# 1          False    False         False         False       False  False
# 2          False    False         False         False       False  False
# 3          False    False         False         False       False  False
# 4          False    False         False         False       False  False
# ...          ...      ...           ...           ...         ...    ...
# 93244      False    False         False         False       False  False
# 93245      False    False         False         False       False  False
# 93246      False    False         False         False       False  False
# 93247      False    False         False         False       False  False
# 93248      False    False         False         False       False  False
#
#        Topic  Question  Data_Value_Unit  Data_Value_Type  ...  GeoLocation  \
# ...

# %%
df1.isnull().sum()
# Out:
# YearStart                         0
# YearEnd                           0
# LocationAbbr                      0
# LocationDesc                      0
# Datasource                        0
# Class                             0
# Topic                             0
# Question                          0
# Data_Value_Unit               93249
# Data_Value_Type                   0
# Data_Value                     9235
# Data_Value_Alt                 9235
# Data_Value_Footnote_Symbol    84014
# Data_Value_Footnote           84014
# Low_Confidence_Limit           9235
# High_Confidence_Limit          9235
# Sample_Size                    9235
# Total                         89919
# Age(years)                    73269
# Education                     79929
# Gender                        86589
# Income                        69939
# Race/Ethnicity                66609
# GeoLocation                    1736
# ClassID                           0
# TopicID                           0
# ...
